# %%
from python_environment_check import check_packages, get_requirements_dict

d = get_requirements_dict()
check_packages(d)
# Out:
# e:\projects\llm_projects\TinyLLM\python_environment_check.py:35: UserWarning: The '__version__' attribute is deprecated and will be removed in MarkupSafe 3.1. Use feature detection, or `importlib.metadata.version("markupsafe")`, instead.
#   version_found = getattr(imported, "__version__", None)
# e:\projects\llm_projects\TinyLLM\.venv\Lib\site-packages\transformers\utils\generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# e:\projects\llm_projects\TinyLLM\.venv\Lib\site-packages\transformers\utils\generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# [OK] accelerate 1.5.2
# [OK] aiohappyeyeballs 2.6.1
# [OK] aiohttp 3.11.13
# [OK] aiosignal 1.3.2
# [OK] annotated-types 0.7.0
# ...
